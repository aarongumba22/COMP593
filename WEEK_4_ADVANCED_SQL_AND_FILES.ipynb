# %% [markdown]
# <a href="https://colab.research.google.com/github/aarongumba22/COMP593/blob/main/WEEK_4_ADVANCED_SQL_AND_FILES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4 - Advanced SQL / Writing Files
#
# In this week's lab, we are going to expand our Really Simple Social Network by adding another table that will record connections between people! Because after all, what good is a social network if you can't ... be social?
#
# Afterwards, we will be in a good position to run a report on the data, and then we can sell it to marketers for a massive profit! Isn't it great how few people read the terms of service? `/s`

# %% [markdown]
# ## Importing our database
# Since we are using a new colab notebook, we will need to reimport our database. Check your D2L Submission if you didn't keep a copy, you should be able to redownload it there. Run the below code block and the file upload picker will appear, after uploading your Database file, check that it appears in the `Files` tab of colab.
#
# Remember that you may need to update the listings before it will appear.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-11e5894f-7cbd-453f-9141-71836ff4a087" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-11e5894f-7cbd-453f-9141-71836ff4a087">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving social_network2.db to social_network2.db

# %% [markdown]
# ## Creating our relationship table
#
# In the code block below, we will be creating a new table in our database for `relationships` with the following parameters:
#
#
# 1.   A primary key column called `id` with the `INTEGER` datatype that is `NOT NULL`
# 2.   A foreign key column called `user_id` that links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 3.   Another foreign key column called `friend_id` that also links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 4.   A `date_created` table with the `DATE` datatype that is `NOT NULL`
#
# The Below codeblock will get you started:

# %%
import sqlite3

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network2.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#The Primary Key column has been provided for you,
#Replace '#!...' with the remaining column names, datatypes, and foreign key declarations.
#Use the Lecture notes and the previous lab if you are unsure.
createRelationshipsTable = """CREATE TABLE IF NOT EXISTS relationships (
                          id integer PRIMARY KEY NOT NULL,
                          user_id integer NOT NULL,
                          friend_id integer NOT NULL, 
                          FOREIGN KEY (user_id) REFERENCES people (id)
                          FOREIGN KEY (user_id) REFERENCES people (id)
                          );"""

#Once again, we will execute the query, persist the changes, and close our connection.
myCursor.execute(createRelationshipsTable)
myConnection.commit()
myConnection.close()

# %% [markdown]
# ## Populating Relationship Data
#
# We're not going to be picky about who knows who - so for the purposes of this lab, we're going to use our own version of an AI matchmaker, the `randrange()` method.
#
# Complete the below codeblock, inserting 1000 new rows into the relationships table.
# Use a random number between `1 - 1000` for the `user_id` and `friend_id` columns. This will link up to the `id` column of the `people` table and effectivly simulate a random network of relationships.
#
# The below code block is purposely sparse, as you should be able to use the patterns you've identified in the previous lab to complete this task.

# %%
import sqlite3
from datetime import datetime #For generating dates and times
from random import randrange #For generating random numbers within a range

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network2.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Complete the below query
query =  """INSERT INTO relationships  (user_id,friend_id)
                  VALUES (?, ?);"""
            
        

for _ in range(1000):
  #Populate the arguments that will be used in the query
  args = (randrange(1,1001),randrange(1,1001))
  #Execute the query
  myCursor.execute(query, args)

#Commit your changes and close the connection.
myConnection.commit()
myConnection.close()

# %%
import sqlite3

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network2.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()



#Complete the below query
query =  """SELECT people.name,COUNT(relationships.id) FROM relationships
           LEFT JOIN people ON relationships.user_id = people.id
           GROUP BY relationships.user_id;
         """
#execute the query of all
myCursor.execute(query)
results = myCursor.fetchall()


#closes the database
myConnection.close()

#open the a file in write mode if not exist create
#loop that prints the user and the amoung of friend to this file then close it
fp = open('report.txt', mode='w')
for result in results:
  name= result[0]
  friends = result[1]
  fp.write(name + " has a total relationship of " + str(friends) + '\n' )


 


# to close the file pointer after you have finished!
fp.close()

# %%
f = open("report.txt", "r")
print(f.read())

f.close()
# Out:
# Tammy Johnson has a total relationship of 2
# Cassidy Mckenzie has a total relationship of 2
# Nichole Spencer has a total relationship of 1
# Kristopher Bryan has a total relationship of 3
# Clayton Baker has a total relationship of 3
# Christine Peterson has a total relationship of 1
# Kathryn Kennedy has a total relationship of 3
# Jerry Mills has a total relationship of 2
# Gary Johnson has a total relationship of 1
# Mark Rhodes has a total relationship of 2
# Erik Cordova has a total relationship of 1
# Michelle Richardson has a total relationship of 1
# Peter Murray has a total relationship of 1
# Craig Schwartz has a total relationship of 2
# Patrick Raymond has a total relationship of 3
# Rachel Carroll PhD has a total relationship of 1
# Todd Miller has a total relationship of 2
# Kristen Pearson has a total relationship of 2
# Mrs. Teresa Hernandez DDS has a total relationship of 1
# Samuel Garcia has a total relationship of 2
# Tanya Beasley has a total relationship of 1
# Kyle Kennedy has a total relationship of 1
# Ashley Phillips has a total relationship of 2
# Patrick Dougherty has a total relationship of 1
# Sarah Reed has a total relationship of 1
# Rachael Franklin has a total relationship of 1
# Edward Maldonado has a total relationship of 1
# Jessica Lee has a total relationship of 2
# Joseph Sims has a total relationship of 1
# Brandy Williams has a total relationship of 3
# Aaron Ballard has a total relationship of 1
# Taylor Church has a total relationship of 1
# Brandy Butler has a total relationship of 2
# Jennifer Nguyen has a total relationship of 1
# David Hamilton has a total relationship of 1
# Cody Gomez has a total relationship of 2
# Amanda Ramos has a total relationship of 1
# Gary Huffman has a total relationship of 2
# Pamela Owen has a total relationship of 1
# Walter Hill has a total relationship of 2
# Brad Powers Jr. has a total relationship of 1
# Jacqueline Lester has a total relationship of 2
# Nathaniel Larson has a total relationship of 2
# David Castro has a total relationship of 2
# Rebecca Thompson has a total relationship of 3
# Sheryl Smith has a total relationship of 1
# Gloria Green has a total relationship of 1
# Cheyenne Pugh has a total relationship of 2
# Steven Smith has a total relationship of 3
# James Landry has a total relationship of 1
# Amanda Davidson has a total relationship of 1
# David Martin has a total relationship of 1
# John Davis has a total relationship of 1
# Amy Gallagher has a total relationship of 1
# Joseph Smith has a total relationship of 2
# Linda Perkins has a total relationship of 1
# Kim Pacheco has a total relationship of 1
# Christian Sanchez has a total relationship of 1
# Pamela Perez has a total relationship of 5
# Barry Sloan has a total relationship of 1
# Megan Goodman has a total relationship of 1
# Kristina Robinson has a total relationship of 1
# Thomas Watkins has a total relationship of 4
# Molly Jimenez has a total relationship of 2
# William Mendoza has a total relationship of 1
# Michael Huang has a total relationship of 3
# Stephanie Newton has a total relationship of 1
# Katelyn Evans has a total relationship of 2
# Joshua Chang has a total relationship of 1
# Stacy Clark has a total relationship of 2
# Robert Fowler has a total relationship of 1
# Paula Durham has a total relationship of 1
# Katrina Juarez has a total relationship of 1
# Dana Duarte has a total relationship of 1
# John Jones has a total relationship of 1
# Robert Spencer has a total relationship of 3
# Ryan Gonzalez has a total relationship of 3
# Jessica Ramirez has a total relationship of 1
# Brittney Jenkins has a total relationship of 1
# Brent Fox has a total relationship of 4
# John Ramirez has a total relationship of 2
# Kayla Moody has a total relationship of 1
# Steven Jennings has a total relationship of 1
# Matthew Reed has a total relationship of 3
# Joshua Bates has a total relationship of 1
# John Lopez has a total relationship of 1
# Andrew Williams has a total relationship of 1
# Isaac Villarreal has a total relationship of 3
# Andrew Coffey has a total relationship of 2
# Maria Chavez has a total relationship of 1
# Wendy Martin has a total relationship of 3
# Mark Fletcher has a total relationship of 1
# Justin Cox has a total relationship of 1
# Brent Stewart has a total relationship of 1
# David Diaz has a total relationship of 1
# James Ford has a total relationship of 2
# Brandon Marks has a total relationship of 1
# Jasmine Miller has a total relationship of 1
# Mr. Rodney Shelton has a total relationship of 2
# Brittany Adams has a total relationship of 2
# Miguel Morris has a total relationship of 1
# Christina Murray has a total relationship of 4
# Rachel Mccarthy has a total relationship of 3
# Tara Navarro has a total relationship of 1
# Kirk Cummings has a total relationship of 1
# Robin Smith has a total relationship of 2
# Heidi Richards has a total relationship of 2
# Donald Franklin has a total relationship of 1
# Sean Douglas has a total relationship of 2
# Michele Harrison has a total relationship of 2
# Timothy Brooks has a total relationship of 1
# Johnny Olson has a total relationship of 1
# Stephanie Aguirre has a total relationship of 1
# Dr. Julia Robertson has a total relationship of 2
# Bobby Cordova has a total relationship of 1
# Timothy Ford has a total relationship of 3
# Allison Smith has a total relationship of 1
# Luke Austin has a total relationship of 1
# Alexander Parker has a total relationship of 3
# Nicholas Smith has a total relationship of 1
# Jeremy Lopez has a total relationship of 1
# Andre Holmes has a total relationship of 2
# Julie Green has a total relationship of 2
# Tonya Mcdonald has a total relationship of 3
# Anthony Ortiz has a total relationship of 1
# Charles Hays has a total relationship of 1
# Chad Gilbert has a total relationship of 2
# Brenda Haynes has a total relationship of 1
# Bradley Velazquez has a total relationship of 3
# Michele Kirby has a total relationship of 2
# Mark Singh has a total relationship of 2
# Brandon Mills has a total relationship of 2
# Michael Johnson has a total relationship of 1
# Bryan Fernandez has a total relationship of 1
# Amy Lowe has a total relationship of 1
# Lisa Cox has a total relationship of 1
# Jason Johnson has a total relationship of 3
# Miguel Sullivan has a total relationship of 3
# Tara Baker has a total relationship of 1
# Tracy Sanchez has a total relationship of 2
# Juan Cook has a total relationship of 3
# Anthony Howell has a total relationship of 1
# Sharon Jackson has a total relationship of 1
# Miranda Johnson has a total relationship of 2
# Cindy Hall has a total relationship of 2
# Jennifer Smith has a total relationship of 1
# David Lloyd has a total relationship of 2
# Traci Martin has a total relationship of 1
# Donald Cowan has a total relationship of 3
# Kristina Martinez has a total relationship of 1
# Bill Cooper has a total relationship of 1
# Brent Johnson has a total relationship of 1
# Noah Bush has a total relationship of 1
# Heather Thomas has a total relationship of 2
# William Schultz has a total relationship of 1
# Peter Richards has a total relationship of 1
# Justin Beard has a total relationship of 2
# Melody Gonzalez has a total relationship of 1
# Chelsea Fisher has a total relationship of 3
# Kayla Watson has a total relationship of 2
# Mary Lucas has a total relationship of 2
# Kevin Bean has a total relationship of 1
# Jesus Ruiz has a total relationship of 1
# Elizabeth Thomas has a total relationship of 1
# Bryan Reed has a total relationship of 1
# Kimberly Mills has a total relationship of 1
# Ryan Smith has a total relationship of 1
# Paul Brown has a total relationship of 3
# Monica Booth MD has a total relationship of 1
# Jennifer Jacobson has a total relationship of 1
# Shawn Bailey has a total relationship of 1
# Maria Rhodes has a total relationship of 1
# William Pena has a total relationship of 1
# Brittany Copeland has a total relationship of 1
# Stephanie Garcia has a total relationship of 1
# Matthew Cole has a total relationship of 3
# Robert Miller has a total relationship of 3
# Ashley Rivera has a total relationship of 1
# Nicholas Parks has a total relationship of 1
# Jeffery Whitaker has a total relationship of 2
# Charles Martin has a total relationship of 1
# Eric Riley has a total relationship of 2
# Robert Neal has a total relationship of 2
# Anna Lawson has a total relationship of 1
# Craig Moran has a total relationship of 1
# Daniel Gordon has a total relationship of 1
# Michael Mclean has a total relationship of 2
# Brittany Stark has a total relationship of 1
# Kimberly Marsh has a total relationship of 1
# Tammy Reilly has a total relationship of 4
# Lindsay Baker has a total relationship of 3
# Matthew Castro has a total relationship of 1
# John Bishop has a total relationship of 1
# Jason Villarreal has a total relationship of 1
# Amanda Brown has a total relationship of 1
# Sara Hernandez has a total relationship of 1
# Terry Smith has a total relationship of 3
# Gloria Rogers has a total relationship of 1
# Joseph Morris has a total relationship of 3
# Katie Moore has a total relationship of 1
# Michael Good has a total relationship of 1
# Joseph Hughes has a total relationship of 2
# Danielle Black has a total relationship of 1
# Christopher Fleming has a total relationship of 1
# Daniel Howard has a total relationship of 2
# Robert Perez has a total relationship of 1
# Brittany Moreno has a total relationship of 2
# Denise Cline has a total relationship of 1
# Beverly Richardson has a total relationship of 2
# Monica Brown has a total relationship of 2
# Ian White has a total relationship of 2
# Tracy Gibson has a total relationship of 1
# Wendy Vasquez has a total relationship of 2
# Randall Cunningham has a total relationship of 1
# Angela Glover has a total relationship of 1
# Leslie Barnett has a total relationship of 1
# William Perkins has a total relationship of 1
# Cody Bryant has a total relationship of 2
# Annette Hansen has a total relationship of 2
# Bryan Rivera has a total relationship of 1
# Frank Barnes has a total relationship of 1
# Dennis Castaneda has a total relationship of 1
# David Ellis has a total relationship of 1
# Patricia Evans has a total relationship of 1
# Raymond Mclaughlin has a total relationship of 2
# Kevin Lopez has a total relationship of 1
# Mr. Nathan Chang DDS has a total relationship of 1
# Eduardo Gallagher has a total relationship of 1
# Bernard James has a total relationship of 1
# Kathleen Santana has a total relationship of 1
# Jennifer Morales has a total relationship of 3
# Thomas Barton has a total relationship of 2
# Robin Wilson has a total relationship of 1
# Allison Richard has a total relationship of 1
# Dennis Martin has a total relationship of 2
# Austin Lane has a total relationship of 1
# Andrea Davis has a total relationship of 2
# Scott Gray has a total relationship of 2
# Susan Jones has a total relationship of 1
# Dana Garcia has a total relationship of 4
# Sandra Sanders has a total relationship of 1
# Nicholas Ibarra has a total relationship of 1
# Ashley Stephens has a total relationship of 3
# Kristin Russell DDS has a total relationship of 1
# Virginia Pierce has a total relationship of 1
# James Zavala has a total relationship of 2
# Dwayne Morales has a total relationship of 3
# Caitlin Rivera has a total relationship of 1
# John Davis has a total relationship of 1
# Willie Martinez has a total relationship of 1
# Daniel Griffith has a total relationship of 5
# Kevin Castillo has a total relationship of 1
# Matthew Brown has a total relationship of 1
# Eddie Hayes has a total relationship of 3
# Shaun Hale has a total relationship of 3
# Joseph Miles has a total relationship of 2
# Sean Rodgers has a total relationship of 1
# Joshua Wheeler has a total relationship of 1
# Heather Rogers has a total relationship of 1
# Roger Villarreal has a total relationship of 1
# Denise Molina has a total relationship of 1
# Teresa Hicks has a total relationship of 2
# Monica Hall DVM has a total relationship of 2
# Jennifer Powell has a total relationship of 1
# Erin Hill has a total relationship of 1
# Willie Collier has a total relationship of 2
# Morgan Bolton has a total relationship of 2
# Angela Phillips has a total relationship of 2
# Philip Orozco has a total relationship of 2
# James Dougherty has a total relationship of 1
# Amanda Anderson has a total relationship of 1
# Rhonda Gilmore has a total relationship of 1
# Toni Johnson has a total relationship of 2
# Brandy Woodard has a total relationship of 1
# Melissa Fields has a total relationship of 2
# Scott Jackson has a total relationship of 2
# Shannon Ramos has a total relationship of 2
# Kyle Washington has a total relationship of 2
# Anne Johnston has a total relationship of 2
# Jeffrey Williams has a total relationship of 1
# Logan Hester has a total relationship of 2
# Jamie Ross has a total relationship of 1
# Lori Larson has a total relationship of 2
# Lisa Salazar has a total relationship of 1
# Catherine Martinez has a total relationship of 1
# Jordan Stuart has a total relationship of 2
# Michael Garcia has a total relationship of 1
# Teresa Vaughan has a total relationship of 1
# Amanda Garcia has a total relationship of 2
# Elizabeth Sullivan has a total relationship of 1
# Susan Oconnor has a total relationship of 2
# Mr. Joseph Jenkins MD has a total relationship of 1
# Erica Chambers has a total relationship of 1
# Helen Stafford has a total relationship of 1
# Mason Miller has a total relationship of 2
# Donald Morrison has a total relationship of 3
# Tiffany Lowe has a total relationship of 1
# Trevor Green has a total relationship of 2
# Katherine Griffin has a total relationship of 1
# Amber Huffman has a total relationship of 2
# Emma Johnson has a total relationship of 1
# Lisa Gonzalez has a total relationship of 1
# Jason Cochran has a total relationship of 1
# Chad Owens has a total relationship of 1
# Timothy Martin has a total relationship of 1
# Levi English has a total relationship of 2
# Sara Rodriguez has a total relationship of 1
# Steven Roberson has a total relationship of 1
# David Reed has a total relationship of 1
# Carol Austin PhD has a total relationship of 1
# Julie Taylor has a total relationship of 3
# Glen Medina has a total relationship of 2
# Shane Marsh has a total relationship of 1
# Melissa Walker has a total relationship of 3
# Joseph Mendoza has a total relationship of 1
# Yvonne Baker has a total relationship of 1
# Steven Ross has a total relationship of 2
# James Johnson has a total relationship of 3
# Courtney Moore has a total relationship of 2
# Robert Barnes has a total relationship of 2
# John Lynn has a total relationship of 2
# Stephanie Thompson has a total relationship of 1
# Mark Long has a total relationship of 1
# Virginia Dougherty has a total relationship of 2
# Rebecca Campbell has a total relationship of 1
# Christopher Carter has a total relationship of 2
# Cory Andrews has a total relationship of 2
# Anne Martinez has a total relationship of 1
# Kimberly Garcia has a total relationship of 3
# Ashley Brown has a total relationship of 1
# Eric Hogan has a total relationship of 3
# Derrick Holder has a total relationship of 1
# David Williams has a total relationship of 1
# Carlos Wilkinson has a total relationship of 1
# Mr. Darryl Evans has a total relationship of 2
# Brianna Rivers has a total relationship of 1
# Alex Best has a total relationship of 2
# Daisy Padilla has a total relationship of 1
# Michael Bell has a total relationship of 1
# Kyle Baker has a total relationship of 1
# Jack Mcdaniel has a total relationship of 1
# Norman Jones has a total relationship of 1
# Michael Taylor has a total relationship of 1
# Shannon Scott has a total relationship of 1
# Mrs. Meghan George has a total relationship of 1
# Ashley Garrison has a total relationship of 1
# Janet Green has a total relationship of 1
# Hunter Contreras has a total relationship of 3
# Briana Davis has a total relationship of 1
# Taylor Sweeney has a total relationship of 3
# Marissa Graham has a total relationship of 1
# Nancy Montes has a total relationship of 2
# Stephanie Burgess has a total relationship of 2
# Melissa Montgomery has a total relationship of 1
# Michael Combs has a total relationship of 2
# Haley Thomas has a total relationship of 2
# Carl Banks has a total relationship of 2
# Megan Forbes has a total relationship of 3
# Antonio Collins has a total relationship of 2
# Joseph Norris has a total relationship of 3
# Keith Nichols has a total relationship of 1
# Angela Rodriguez has a total relationship of 1
# Brandy Day has a total relationship of 1
# Danielle Wagner has a total relationship of 1
# Jean Clark has a total relationship of 3
# Joseph Davis has a total relationship of 2
# Mark Mcguire has a total relationship of 3
# Jennifer Baker has a total relationship of 1
# Mark Todd has a total relationship of 1
# Abigail Welch has a total relationship of 1
# Steven Hernandez has a total relationship of 1
# David Rush has a total relationship of 1
# Jodi Mcdonald has a total relationship of 2
# Bethany Green has a total relationship of 2
# Dustin Pennington has a total relationship of 1
# Erin Friedman has a total relationship of 1
# Victor Schmidt has a total relationship of 1
# Katie Brock has a total relationship of 2
# Robert Gregory has a total relationship of 1
# Danielle Morris has a total relationship of 1
# Shannon Wilson has a total relationship of 2
# Zachary Stevens has a total relationship of 2
# Vanessa Ramos has a total relationship of 1
# Richard Savage has a total relationship of 1
# Kristin Smith has a total relationship of 2
# Dr. Emily Hill MD has a total relationship of 2
# Chase Brown has a total relationship of 1
# Melissa Graham has a total relationship of 3
# John Rodriguez has a total relationship of 4
# Clayton Dunlap has a total relationship of 2
# Tasha Rivera has a total relationship of 1
# Morgan Grimes MD has a total relationship of 2
# Nathaniel Brown has a total relationship of 4
# Chase Sherman has a total relationship of 2
# Andrea Rivera has a total relationship of 1
# David Hernandez has a total relationship of 2
# Joshua Kelley has a total relationship of 2
# Pamela Lawson has a total relationship of 1
# Victor Edwards has a total relationship of 1
# Susan Peterson has a total relationship of 1
# Brian Everett has a total relationship of 2
# Kelly Gonzalez has a total relationship of 1
# Jim Arellano has a total relationship of 1
# Kelsey Reid has a total relationship of 1
# Krista Ward has a total relationship of 2
# Heather Long has a total relationship of 2
# Brandy Kelly has a total relationship of 1
# Jo Cruz has a total relationship of 2
# Matthew Fisher has a total relationship of 1
# Stephanie Perry has a total relationship of 1
# Jonathon Black has a total relationship of 2
# Jeremy Rogers has a total relationship of 1
# Kimberly Campbell has a total relationship of 2
# Martin Blake has a total relationship of 1
# Phillip Porter has a total relationship of 2
# Jennifer Morrison has a total relationship of 1
# Jonathan Martin has a total relationship of 1
# Jacob Ross has a total relationship of 1
# Melissa Stone has a total relationship of 2
# Bruce Bell has a total relationship of 1
# Nichole Martinez has a total relationship of 1
# Gary Crawford DDS has a total relationship of 2
# Brian Hernandez has a total relationship of 1
# Thomas Herring has a total relationship of 1
# Angela Hernandez has a total relationship of 3
# Jennifer Nelson has a total relationship of 2
# Aaron Kirk has a total relationship of 1
# Alexandra Taylor has a total relationship of 1
# Matthew Pruitt has a total relationship of 2
# Jody Hardy has a total relationship of 2
# Ana Fischer has a total relationship of 2
# Alexander Deleon has a total relationship of 1
# Tammy Mathis has a total relationship of 1
# Susan Robinson has a total relationship of 2
# Jason Williams has a total relationship of 2
# Lisa Hall has a total relationship of 3
# Elaine Gardner has a total relationship of 1
# Steven Prince has a total relationship of 1
# Cynthia Huff has a total relationship of 2
# Jeremy Cruz has a total relationship of 1
# Mr. Rodney Rush Jr. has a total relationship of 3
# Shane Perez has a total relationship of 2
# Robert Rivera has a total relationship of 1
# Melissa Williams has a total relationship of 1
# Joseph Fisher has a total relationship of 3
# Keith Howard MD has a total relationship of 1
# Katherine Davis has a total relationship of 2
# Mark Holmes has a total relationship of 2
# Zachary Phillips has a total relationship of 1
# Patrick Ford has a total relationship of 3
# Judith Graham has a total relationship of 2
# Cody Jones has a total relationship of 2
# Connor Smith has a total relationship of 1
# Julia Cameron has a total relationship of 1
# Kyle Davis has a total relationship of 4
# Julie Anderson has a total relationship of 1
# Erin Garcia has a total relationship of 2
# Sarah Walker has a total relationship of 2
# Derek Franklin has a total relationship of 1

# %% [markdown]
# ## Building our Report
#
# Now that our AI Matchmaker has generated our network of relationships, a marketing firm is offering us boatloads of cash for information about the amount of friends the users of our social network have.
#
# The request is to return the name of each user, and the total number of relationships they have made.
#
# If this was explained in awkward pseudo code, it might go something like this:
# ```
# SELECT all relationships
# JOIN them to the people they belong to
# GROUP the results by the person's ID
# return the person's name and COUNT of their relationships
# ```
#
# After you have collected the data, you will need to write it to a `.txt` file.
#
# **Your submission will include the report `.txt` file, the copy of your updated `social_network.db` file, and a link to the colab notebook.**
#
# Look at the aggregate functions from Week 3 and the Join examples from Week 4. There are a few different ways that you can structure a query to reach the correct answer.
#
# **At a minimum, you will need to use a `LEFT JOIN` statement, a `GROUP BY` statement, and a `COUNT()` aggregate function.**
#
# The below code block will get you started:

# %% [markdown]
# ### Challenge: Write a CSV file
#
# **This challenge isn't for extra marks, it's an opportunity for you to engage in some self guided discovery, only if you feel like it, and only if you have time.**
#
# If you want to challenge yourself, alter the report so that it conforms with the `.csv` file type. There are a number of ways to do this, you can use the `Pandas` module, the `csv` module, or manually.
